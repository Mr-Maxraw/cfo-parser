# %%
from openpyxl import Workbook, load_workbook
import pandas as pd
import numpy as np

# %%
from szp_funcs import load_month, print_df

# %%
month = 'may'

# %%
res = load_month(month)

# %%
prep = res[['inn', 'snils', 'job_' + month]].rename(columns={'job_' + month: 'job'})

# %%
prep = prep.groupby(['inn', 'job']).nunique().unstack().reset_index()

# %%
prep.columns = [i[1] for i in prep.columns]

# %%
prep
# Out:
#                  Администратор  Администратор баз данных  \
# 0    5003021368            NaN                       1.0
# 1    5003021495            3.0                       NaN
# 2    5003021640            2.0                       NaN
# 3    5003096290            4.0                       4.0
# 4    5030032182            NaN                       NaN
# ..          ...            ...                       ...
# 590  7743940590            NaN                       1.0
# 591  9705101759            NaN                       NaN
# 592  9715206976            2.0                       1.0
# 593  9715217689            NaN                       NaN
# 594  9718071371            NaN                       NaN
#
#      Аккомпаниатор-концертмейстер  Аналитик  Архивариус  Ассистент  \
# 0                             NaN       NaN         NaN        NaN
# 1                             NaN       NaN         NaN        NaN
# 2                             NaN       NaN         NaN        4.0
# ...

# %%
print_df(prep, 'Учреждения по должностям за ' + month)
